# %%
# !pip install ckiptagger[gdown,tf]
# !pip install rouge

import sys
sys.path.append('/kaggle/input/adl-homework2/')

# %%
# !pip install -r /kaggle/input/summarize-adl-hw2/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.2 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.6 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=ed007c8386ff25aadc7c695ba21316d986afc3a3775df96805090defb1e648f4
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# ...

# %%
import wandb
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
wandb_api_key = user_secrets.get_secret("wandb_api_key") 
wandb.login(key=wandb_api_key) #f647d6cfd571487fcdb4fb230c927cd2d675252a


# from huggingface_hub import notebook_login

# notebook_login()
import huggingface_hub
huggingface_hub.login(token='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')

# %%
# !python /kaggle/input/summarize-adl-hw2/run_summarization_no_trainer.py \
    --model_name_or_path google/mt5-small \
    --train_file /kaggle/input/adl-homework2/train.jsonl \
    --validation_file /kaggle/input/adl-homework2/public.jsonl \
    --text_column maintext \
    --summary_column title \
    --num_beams 3 \
    --per_device_train_batch_size=2 \
    --gradient_accumulation_steps=4 \
    --source_prefix "summarize: " \
    --output_dir /kaggle/working/
# Out:
# ...
# Extracting data files: 100%|█████████████████████| 2/2 [00:00<00:00, 827.28it/s]
# Traceback (most recent call last):
#   File "/kaggle/input/summarize-adl-hw2/run_summarization_no_trainer.py", line 779, in <module>
#     main()
#   File "/kaggle/input/summarize-adl-hw2/run_summarization_no_trainer.py", line 399, in main
#     raw_datasets = load_dataset(args.dataset_name, args.dataset_config_name)
#   File "/opt/conda/lib/python3.10/site-packages/datasets/load.py", line 1691, in load_dataset
#     builder_instance.download_and_prepare(
#   File "/opt/conda/lib/python3.10/site-packages/datasets/builder.py", line 605, in download_and_prepare
#     self._download_and_prepare(
#   File "/opt/conda/lib/python3.10/site-packages/datasets/builder.py", line 694, in _download_and_prepare
#     self._prepare_split(split_generator, **prepare_split_kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/datasets/builder.py", line 1154, in _prepare_split
#     writer.write_table(table)
# ...
